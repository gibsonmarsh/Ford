# %% [markdown]
# <a href="https://colab.research.google.com/github/gibsonmarsh/Ford/blob/main/project_2_part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
url = 'https://raw.githubusercontent.com/gibsonmarsh/Ford/main/cost-of-living%20(2).csv'
df = pd.read_csv(url)
df.T
# Out:
#                                                     0   \
# Unnamed: 0                Meal, Inexpensive Restaurant
# Saint Petersburg, Russia                          7.34
# Istanbul, Turkey                                  4.58
# Izmir, Turkey                                     3.06
# Helsinki, Finland                                 12.0
# ...                                                ...
# Melbourne, Australia                             10.22
# Perth, Australia                                 12.43
# Sydney, Australia                                11.81
# Alexandria, Egypt                                 2.81
# Quito, Ecuador                                    3.59
#
#                                                                          1   \
# Unnamed: 0                Meal for 2 People, Mid-range Restaurant, Three...
# Saint Petersburg, Russia                                              29.35
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Below is coorelation between the variables above.

# %%
print(df)
df.corr()
# Out:
#                                            Unnamed: 0  \
# 0                        Meal, Inexpensive Restaurant
# 1   Meal for 2 People, Mid-range Restaurant, Three...
# 2      McMeal at McDonalds (or Equivalent Combo Meal)
# 3                   Domestic Beer (0.5 liter draught)
# 4                   Imported Beer (0.33 liter bottle)
# 5                      Coke/Pepsi (0.33 liter bottle)
# 6                          Water (0.33 liter bottle)
# 7                           Milk (regular), (1 liter)
# 8                    Loaf of Fresh White Bread (500g)
# 9                                 Eggs (regular) (12)
# 10                                 Local Cheese (1kg)
# 11                           Water (1.5 liter bottle)
# 12                         Bottle of Wine (Mid-Range)
# 13                   Domestic Beer (0.5 liter bottle)
# 14                  Imported Beer (0.33 liter bottle)
# 15                      Cigarettes 20 Pack (Marlboro)
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                                            Unnamed: 0  \
# 0                        Meal, Inexpensive Restaurant
# 1   Meal for 2 People, Mid-range Restaurant, Three...
# 2      McMeal at McDonalds (or Equivalent Combo Meal)
# 3                   Domestic Beer (0.5 liter draught)
# 4                   Imported Beer (0.33 liter bottle)
# 5                      Coke/Pepsi (0.33 liter bottle)
# 6                          Water (0.33 liter bottle)
# 7                           Milk (regular), (1 liter)
# 8                    Loaf of Fresh White Bread (500g)
# 9                                 Eggs (regular) (12)
# 10                                 Local Cheese (1kg)
# 11                           Water (1.5 liter bottle)
# 12                         Bottle of Wine (Mid-Range)
# 13                   Domestic Beer (0.5 liter bottle)
# 14                  Imported Beer (0.33 liter bottle)
# 15                      Cigarettes 20 Pack (Marlboro)
# ...

# %%
# path of data 
path = 'https://raw.githubusercontent.com/gibsonmarsh/Ford/main/cost-of-living%20(2).csv'
df = pd.read_csv(path)
df.head()
# Out:
#                                           Unnamed: 0  \
# 0                       Meal, Inexpensive Restaurant
# 1  Meal for 2 People, Mid-range Restaurant, Three...
# 2     McMeal at McDonalds (or Equivalent Combo Meal)
# 3                  Domestic Beer (0.5 liter draught)
# 4                  Imported Beer (0.33 liter bottle)
#
#    Saint Petersburg, Russia  Istanbul, Turkey  Izmir, Turkey  \
# 0                      7.34              4.58           3.06
# 1                     29.35             15.28          12.22
# 2                      4.40              3.82           3.06
# 3                      2.20              3.06           2.29
# 4                      2.20              3.06           2.75
#
#    Helsinki, Finland  Chisinau, Moldova  Milan, Italy  Cairo, Egypt  \
# 0              12.00               4.67          15.0          3.38
# 1              65.00              20.74          60.0         17.48
# ...

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot
plt.ylim(0,)
# Out:
# (0.0, 1.0)
